# %% [markdown]
# 1. Baza danych nyc_streets zawiera 19091 rekordów. Jest to suma wszystkich kolumn w bazie danych.

# %%
from IPython import display
display.Image("img/1.jpg")

# %% [markdown]
# 2. Suma wszystkich ulic zaczynających się na listere B, Q lub M to 1385.

# %%
display.Image("img/1.jpg")

# %% [markdown]
# 3. Populacja Nowego Yourku wynosi 8175032, jest to suma populacji z wszytich lokacji.

# %%
display.Image("img/3.jpg")

# %% [markdown]
# 4. Suma populacji Queens , Maanhattanu i Bronxu to kolejno 2230621,1585873 i 1385108

# %%
display.Image("img/4.jpg")

# %% [markdown]
# 5. Liczba dzielnic poszczególnych gmin

# %%
display.Image("img/5.jpg")

# %% [markdown]
# 4. Suma populacji Queens , Maanhattanu i Bronxu to kolejno 2230621,1585873 i 1385108

# %% [markdown]
# ![4.jpg](attachment:4.jpg)

# %% [markdown]
# 5. Liczba dzielnic poszczególnych gmin

# %% [markdown]
# ![5.jpg](attachment:5.jpg)
