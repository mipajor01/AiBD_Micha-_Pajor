# %% [markdown]
# Michał Pajor
#
# ZAD. 3

# %%
import numpy as np
import matplotlib.pyplot as plt

def kwardz_fun(x,min_a,max_a):
    y=[]
    for i in x:
        y.append(i**2+5)
    plt.plot(x,y,label='f^2+5')
    plt.grid('on')
    plt.title('Wykres funkcji dla przedziału od' + str(min_a) + ' do ' + str(max_a))
    plt.xlabel('oś x')
    plt.ylabel('oś y')
    plt.xlim(min_a,max_a)
    plt.legend(loc = 4)
    plt.show()
x = np.linspace(-1,1,2000)
kwardz_fun(x,-1,1)
x = np.linspace(-6,6,2000)
kwardz_fun(x,-6,6)
x = np.linspace(0,5,2000)
kwardz_fun(x,0,5)

# %% [markdown]
# ZAD. 4

# %%
import pandas as pd

data = pd.DataFrame({'name':['Michał','Kuba','Antonina','Piotr','Anna'],'surname':['Pajor','Kostecki','Bernat','Grygier','Urbanek'],'age':[21,23,18,19,35],'sex':['m','m','f','m','f']})
print(data.info())
print(data.describe())
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
# None
#              age
# count   5.000000
# mean   23.200000
# std     6.870226
# min    18.000000
# 25%    19.000000
# 50%    21.000000
# 75%    23.000000
# max    35.000000
#        name   surname  age sex
# 0    Michał     Pajor   21   m
# 1      Kuba  Kostecki   23   m
# 2  Antonina    Bernat   18   f
# 3     Piotr   Grygier   19   m
# 4      Anna   Urbanek   35   f
